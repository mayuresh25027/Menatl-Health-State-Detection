# %%
import pandas as pd

# %%
series =pd.Series(["BMW","Honda","Toyota"])

# %%
series
# Out:
# 0       BMW
# 1     Honda
# 2    Toyota
# dtype: object

# %%
color =pd.Series(["white","Black","orange"])

# %%
color
# Out:
# 0     white
# 1     Black
# 2    orange
# dtype: object

# %%
df=pd.DataFrame({"car_model":series,"Car_color":color})

# %%
df
# Out:
#   car_model Car_color
# 0       BMW     white
# 1     Honda     Black
# 2    Toyota    orange

# %%
car_sales=pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# exporting dataFrames to other csv

car_sales.to_csv("exported-car-sales.csv",index=False)

# %%
exported_car_sales=pd.read_csv("exported-car-sales.csv")
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_columns=car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.head(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %% [markdown]
# ## loc and iloc

# %%
#its actully the location containg all index[X]


car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
#iloc stands for index location where denotes for index 3


car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
## slicing file_name.iloc[:3]

car_sales.iloc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
##can use car_sales["Make"] or car_sale.make (given varialbe should'nt have spaces)


car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
Tyoyta_car_sales = car_sales[car_sales["Make"]=="Toyota"]

Tyoyta_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
##corsstab is used to comapre two colums of same file



pd.crosstab(car_sales["Doors"],car_sales["Make"])
# Out:
# Make   BMW  Honda  Nissan  Toyota
# Doors
# 3        0      0       0       1
# 4        0      3       2       3
# 5        1      0       0       0

# %%
car_sales.groupby(["Make"]).mean().
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
 # %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# car_sales

# %%
car_sales["Price"]=car_sales["Price"].astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   6999
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3499
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   6999
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales.Price.hist()
# Out:
# <AxesSubplot:>

# %%
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %%
#what to do when we have some missing values es NaN


#we use car_sales["Parameter"] =car_sales.["Parameter"].fillna(car_sales.["Parameter"].mean(),inplace=True )

# %%
#inorder to drop the missing data we use 

#car_sales_dropped =car_sales.dropna()

# %%
#colums from series

seat_column = pd.Series([5,5,5,5,5])

#new column in set

car_sales["Seats"]=seat_column.astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  Toyota  White         150043      4   4000    5.0
# 1   Honda    Red          87899      4   5000    5.0
# 2  Toyota   Blue          32549      3   6999    5.0
# 3     BMW  Black          11179      5  22000    5.0
# 4  Nissan  White         213095      4   3499    5.0
# 5  Toyota  Green          99213      4   4500    NaN
# 6   Honda   Blue          45698      4   7500    NaN
# 7   Honda   Blue          54738      4   6999    NaN
# 8  Toyota  White          60000      4   6250    NaN
# 9  Nissan  White          31600      4   9700    NaN

# %%
car_sales["Seats"].mean()
# Out:
# 5.0

# %%
car_sales["Seats"].fillna(car_sales["Seats"].mean(),inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  Toyota  White         150043      4   4000    5.0
# 1   Honda    Red          87899      4   5000    5.0
# 2  Toyota   Blue          32549      3   6999    5.0
# 3     BMW  Black          11179      5  22000    5.0
# 4  Nissan  White         213095      4   3499    5.0
# 5  Toyota  Green          99213      4   4500    5.0
# 6   Honda   Blue          45698      4   7500    5.0
# 7   Honda   Blue          54738      4   6999    5.0
# 8  Toyota  White          60000      4   6250    5.0
# 9  Nissan  White          31600      4   9700    5.0

# %%
fuel_eco =[8.9,8.8,9.6,7.5,6,9.9,10.5,6.6,15,11]
car_sales["fuel_per_100km"]=fuel_eco
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel_per_100km
# 0  Toyota  White         150043      4   4000    5.0             8.9
# 1   Honda    Red          87899      4   5000    5.0             8.8
# 2  Toyota   Blue          32549      3   6999    5.0             9.6
# 3     BMW  Black          11179      5  22000    5.0             7.5
# 4  Nissan  White         213095      4   3499    5.0             6.0
# 5  Toyota  Green          99213      4   4500    5.0             9.9
# 6   Honda   Blue          45698      4   7500    5.0            10.5
# 7   Honda   Blue          54738      4   6999    5.0             6.6
# 8  Toyota  White          60000      4   6250    5.0            15.0
# 9  Nissan  White          31600      4   9700    5.0            11.0

# %%
car_sales["Best value for money"]=car_sales["Odometer (KM)"]/(car_sales["fuel_per_100km"]*100)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel_per_100km  \
# 0  Toyota  White         150043      4   4000    5.0             8.9
# 1   Honda    Red          87899      4   5000    5.0             8.8
# 2  Toyota   Blue          32549      3   6999    5.0             9.6
# 3     BMW  Black          11179      5  22000    5.0             7.5
# 4  Nissan  White         213095      4   3499    5.0             6.0
# 5  Toyota  Green          99213      4   4500    5.0             9.9
# 6   Honda   Blue          45698      4   7500    5.0            10.5
# 7   Honda   Blue          54738      4   6999    5.0             6.6
# 8  Toyota  White          60000      4   6250    5.0            15.0
# 9  Nissan  White          31600      4   9700    5.0            11.0
#
#    Best value for money
# 0            168.587640
# 1             99.885227
# 2             33.905208
# 3             14.905333
# 4            355.158333
# 5            100.215152
# 6             43.521905
# ...

# %%
#in order to drop a column we use


#car_sales = car_sales.drop("fuel_per_100km",axis=1)

# %%
#in order to change the order


random_sample = car_sales.sample(frac=1)

# %%
random_sample
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel_per_100km  \
# 4  Nissan  White         213095      4   3499    5.0             6.0
# 2  Toyota   Blue          32549      3   6999    5.0             9.6
# 6   Honda   Blue          45698      4   7500    5.0            10.5
# 1   Honda    Red          87899      4   5000    5.0             8.8
# 0  Toyota  White         150043      4   4000    5.0             8.9
# 3     BMW  Black          11179      5  22000    5.0             7.5
# 8  Toyota  White          60000      4   6250    5.0            15.0
# 9  Nissan  White          31600      4   9700    5.0            11.0
# 5  Toyota  Green          99213      4   4500    5.0             9.9
# 7   Honda   Blue          54738      4   6999    5.0             6.6
#
#    Best value for money
# 4            355.158333
# 2             33.905208
# 6             43.521905
# 1             99.885227
# 0            168.587640
# 3             14.905333
# 8             40.000000
# ...

# %%
random_sample.reset_index(drop=True,inplace=True)

# %%
random_sample
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel_per_100km  \
# 0  Nissan  White         213095      4   3499    5.0             6.0
# 1  Toyota   Blue          32549      3   6999    5.0             9.6
# 2   Honda   Blue          45698      4   7500    5.0            10.5
# 3   Honda    Red          87899      4   5000    5.0             8.8
# 4  Toyota  White         150043      4   4000    5.0             8.9
# 5     BMW  Black          11179      5  22000    5.0             7.5
# 6  Toyota  White          60000      4   6250    5.0            15.0
# 7  Nissan  White          31600      4   9700    5.0            11.0
# 8  Toyota  Green          99213      4   4500    5.0             9.9
# 9   Honda   Blue          54738      4   6999    5.0             6.6
#
#    Best value for money
# 0            355.158333
# 1             33.905208
# 2             43.521905
# 3             99.885227
# 4            168.587640
# 5             14.905333
# 6             40.000000
# ...
